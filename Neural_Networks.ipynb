# %% [markdown]
# <a href="https://colab.research.google.com/github/Moksh45/TensorFlow/blob/main/Neural_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Neural Network**

# %%
# %tensorflow_version 2.x  # this line is not required unless you are in a notebook
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
fashion_mnist = keras.datasets.fashion_mnist  # load dataset

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()  # split into tetsing and training
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_images[0,23,23]  # let's have a look at one pixel
# Out:
# 194

# %%
train_labels[:10]
# Out:
# array([9, 0, 0, 3, 0, 2, 7, 2, 5, 5], dtype=uint8)

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %% [markdown]
# # ***Building the Model***

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),  # input layer (1)
    keras.layers.Dense(128, activation='relu'),  # hidden layer (2)
    keras.layers.Dense(10, activation='softmax') # output layer (3)
])

# %%
model.compile(optimizer='adam',     #using adam algo
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])


model.fit(train_images, train_labels, epochs=10)  # we pass the data, labels and epochs and watch the magic!
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1378 - accuracy: 0.9474
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1343 - accuracy: 0.9508
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1314 - accuracy: 0.9503
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1284 - accuracy: 0.9518
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1263 - accuracy: 0.9535
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1234 - accuracy: 0.9527
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1252 - accuracy: 0.9520
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1207 - accuracy: 0.9546
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1162 - accuracy: 0.9557
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1139 - accuracy: 0.9577

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=1) 

print('Test accuracy:', test_acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4503 - accuracy: 0.8847
# Test accuracy: 0.8847000002861023

# %% [markdown]
# # **Making Predictions**

# %%
for i in range(0,51):

  predictions = model.predict(test_images)
  print(class_names[np.argmax(predictions[i])])
  plt.figure()
  plt.imshow(train_images[i])
  plt.colorbar()
  plt.grid(False)
  plt.show()
# Out:
# 313/313 [==============================] - 0s 2ms/step
# Ankle boot
# 313/313 [==============================] - 1s 2ms/step
# Pullover
# 313/313 [==============================] - 1s 2ms/step
# Trouser
# 313/313 [==============================] - 1s 2ms/step
# Trouser
# 313/313 [==============================] - 1s 2ms/step
# Shirt
# 313/313 [==============================] - 0s 2ms/step
# Trouser
# 313/313 [==============================] - 1s 2ms/step
# Coat
# 313/313 [==============================] - 1s 2ms/step
# Shirt
# 313/313 [==============================] - 0s 2ms/step
# Sandal
# 313/313 [==============================] - 1s 2ms/step
# Sneaker
# 313/313 [==============================] - 1s 2ms/step
# Coat
# 313/313 [==============================] - 1s 2ms/step
# Sandal
# 313/313 [==============================] - 0s 2ms/step
# Sandal
# 313/313 [==============================] - 1s 2ms/step
# Dress
# 313/313 [==============================] - 1s 2ms/step
# Coat
# 313/313 [==============================] - 1s 2ms/step
# Trouser
# 313/313 [==============================] - 0s 2ms/step
# Pullover
# 313/313 [==============================] - 1s 2ms/step
# Pullover
# 313/313 [==============================] - 1s 2ms/step
# Bag
# 313/313 [==============================] - 1s 2ms/step
# T-shirt/top
# 313/313 [==============================] - 1s 2ms/step
# Pullover
# 313/313 [==============================] - 1s 2ms/step
# Sandal
# 313/313 [==============================] - 1s 2ms/step
# Sneaker
# 313/313 [==============================] - 0s 2ms/step
# Sandal
# 313/313 [==============================] - 1s 2ms/step
# Trouser
# 313/313 [==============================] - 1s 2ms/step
# Pullover
# 313/313 [==============================] - 1s 2ms/step
# Shirt
# 313/313 [==============================] - 1s 2ms/step
# T-shirt/top
# 313/313 [==============================] - 1s 2ms/step
# Ankle boot
# 313/313 [==============================] - 1s 2ms/step
# Coat
# 313/313 [==============================] - 1s 2ms/step
# Bag
# 313/313 [==============================] - 1s 2ms/step
# Bag
# 313/313 [==============================] - 1s 2ms/step
# Dress
# 313/313 [==============================] - 1s 2ms/step
# Dress
# 313/313 [==============================] - 1s 2ms/step
# Bag
# 313/313 [==============================] - 1s 2ms/step
# T-shirt/top
# 313/313 [==============================] - 1s 2ms/step
# Sneaker
# 313/313 [==============================] - 1s 2ms/step
# Sandal
# 313/313 [==============================] - 1s 2ms/step
# Sneaker
# 313/313 [==============================] - 1s 2ms/step
# Ankle boot
# 313/313 [==============================] - 1s 2ms/step
# T-shirt/top
# 313/313 [==============================] - 1s 2ms/step
# Trouser
# 313/313 [==============================] - 1s 2ms/step
# Shirt
# 313/313 [==============================] - 1s 2ms/step
# Sneaker
# 313/313 [==============================] - 1s 2ms/step
# Shirt
# 313/313 [==============================] - 1s 2ms/step
# Sneaker
# 313/313 [==============================] - 1s 2ms/step
# Pullover
# 313/313 [==============================] - 1s 2ms/step
# Trouser
# 313/313 [==============================] - 1s 2ms/step
# Pullover
# 313/313 [==============================] - 1s 2ms/step
# Shirt
# 313/313 [==============================] - 1s 2ms/step
# Coat

# %% [markdown]
# # **Verifying Predictions**

# %%
COLOR = 'white'
plt.rcParams['text.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR

def predict(model, image, correct_label):
  class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
  prediction = model.predict(np.array([image]))
  predicted_class = class_names[np.argmax(prediction)]

  show_image(image, class_names[correct_label], predicted_class)


def show_image(img, label, guess):
  print("Excpected: " + label)
  print("Guess: " + guess)
  plt.figure()
  plt.imshow(img, cmap=plt.cm.binary)
  plt.title("Excpected: " + label)
  plt.xlabel("Guess: " + guess)
  plt.colorbar()
  plt.grid(False)
  plt.show()


def get_number():
  while True:
    num = input("Pick a number: ")
    if num.isdigit():
      num = int(num)
      if 0 <= num <= 1000:
        return int(num)
    else:
      print("Try again...")

num = get_number()
image = test_images[num]
label = test_labels[num]
predict(model, image, label)
# Out:
# Pick a number: 232
# 1/1 [==============================] - 0s 19ms/step
# Excpected: Ankle boot
# Guess: Ankle boot
